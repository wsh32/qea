# %%
import pandas as pd

# %%
player_data = pd.read_csv('data/People.csv')

# %%
def get_playerid(last_name, first_name=None):
    if first_name:
        playerid = player_data.loc[(player_data['nameLast'] == last_name) & (player_data['nameFirst'] == first_name)]['playerID']
    else:
        playerid = player_data.loc[(player_data['nameLast'] == last_name)]['playerID']
    return playerid

# %%
appearance_data = pd.read_csv('data/Appearances.csv')

# %%
k = get_playerid('Jansen', 'Kenley')
appearance_data.loc[appearance_data['playerID'].isin(k)]
# Out:
#         yearID teamID lgID   playerID  G_all   GS  G_batting  G_defense  G_p  \
# 93399     2010    LAN   NL  janseke01     26  0.0         26       25.0   25
# 94771     2011    LAN   NL  janseke01     51  0.0         48       51.0   51
# 96176     2012    LAN   NL  janseke01     65  0.0         64       65.0   65
# 97589     2013    LAN   NL  janseke01     75  0.0         70       75.0   75
# 98999     2014    LAN   NL  janseke01     68  0.0         64       68.0   68
# 100461    2015    LAN   NL  janseke01     54  0.0         51       54.0   54
# 101931    2016    LAN   NL  janseke01     72  0.0         68       72.0   72
# 103434    2017    LAN   NL  janseke01     65  0.0         59       65.0   65
# 104943    2018    LAN   NL  janseke01     69  0.0         65       69.0   69
# 106499    2019    LAN   NL  janseke01     62  0.0         59       62.0   62
#
#         G_c  ...  G_2b  G_3b  G_ss  G_lf  G_cf  G_rf  G_of  G_dh  G_ph  G_pr
# ...

# %%
k
# Out:
# 8731    janseke01
# Name: playerID, dtype: object

# %%
fielding_data = pd.read_csv('data/Fielding.csv')

True in (fielding_data.loc[fielding_data['playerID'].isin(k)]['POS'] == 'P').values
# Out:
# True

# %%
pitching_data = pd.read_csv('data/Pitching.csv')
pitching_data_recent = pitching_data[pitching_data['yearID'] >= 2000]

# %%
player_data.loc[(player_data['nameLast'] == 'Sale')]
# Out:
#        playerID  birthYear  birthMonth  birthDay birthCountry birthState  \
# 15679  salech01     1989.0         3.0      30.0          USA         FL
# 15680  salefr01     1902.0         5.0       2.0          USA         SC
#
#       birthCity  deathYear  deathMonth  deathDay  ... nameLast  \
# 15679  Lakeland        NaN         NaN       NaN  ...     Sale
# 15680   Chester     1956.0         5.0      27.0  ...     Sale
#
#             nameGiven weight height bats throws       debut   finalGame  \
# 15679     Christopher  180.0   78.0    L      L  2010-08-06  2019-08-13
# 15680  Frederick Link  160.0   69.0    R      R  1924-06-30  1924-06-30
#
#         retroID   bbrefID
# 15679  salec001  salech01
# 15680  salef101  salefr01
#
# [2 rows x 24 columns]

# %%
k = get_playerid('Sale')
pitching_data.loc[pitching_data['playerID'].isin(k)]
# Out:
#        playerID  yearID  stint teamID lgID   W   L   G  GS  CG  ...  IBB  WP  \
# 7585   salefr01    1924      1    PIT   NL   0   0   1   0   0  ...  NaN   0
# 40293  salech01    2010      1    CHA   AL   2   1  21   0   0  ...  0.0   1
# 40995  salech01    2011      1    CHA   AL   2   2  58   0   0  ...  3.0   2
# 41723  salech01    2012      1    CHA   AL  17   8  30  29   1  ...  5.0   6
# 42457  salech01    2013      1    CHA   AL  11  14  30  30   4  ...  2.0   8
# 43190  salech01    2014      1    CHA   AL  12   4  26  26   2  ...  2.0   3
# 44003  salech01    2015      1    CHA   AL  13  11  31  31   1  ...  0.0   7
# 44808  salech01    2016      1    CHA   AL  17  10  32  32   6  ...  2.0   2
# 45634  salech01    2017      1    BOS   AL  17   8  32  32   1  ...  0.0   3
# 46518  salech01    2018      1    BOS   AL  12   4  27  27   0  ...  0.0   4
# 47428  salech01    2019      1    BOS   AL   6  11  25  25   1  ...  0.0   2
#
# ...

# %%
batting_data = pd.read_csv('data/Batting.csv')
k = get_playerid('Betts')
batting_data.loc[batting_data['playerID'].isin(k)]
# Out:
#          playerID  yearID  stint teamID lgID    G   AB    R    H  2B  ...  \
# 8998    bettsha01    1903      1    SLN   NL    1    3    0    0   0  ...
# 13864   bettsha01    1913      1    CIN   NL    1    1    0    0   0  ...
# 18177   bettshu01    1920      1    PHI   NL   27   25    2    2   0  ...
# 18693   bettshu01    1921      1    PHI   NL   32   30    2    8   1  ...
# 19214   bettshu01    1922      1    PHI   NL    7    4    1    0   0  ...
# 19737   bettshu01    1923      1    PHI   NL   20   31    0    3   0  ...
# 20265   bettshu01    1924      1    PHI   NL   38   45    7    7   0  ...
# 20813   bettshu01    1925      1    PHI   NL   37   34    5   10   2  ...
# 24533   bettshu01    1932      1    BSN   NL   31   79    5   19   0  ...
# 25052   bettshu01    1933      1    BSN   NL   35   76    3   17   1  ...
# 25546   bettshu01    1934      1    BSN   NL   40   69    3   13   1  ...
# 26063   bettshu01    1935      1    BSN   NL   44   44    1    7   0  ...
# ...

# %%
salary_data = pd.read_csv('data/Salaries.csv')
k = get_playerid('Molina')
salary_data.loc[salary_data['playerID'].isin(k)]
# Out:
#        yearID teamID lgID   playerID    salary
# 9041     1996    OAK   AL  moliniz01    109000
# 9969     1997    OAK   AL  moliniz01    152000
# 10948    1998    OAK   AL  moliniz01    175000
# 11279    1999    ANA   AL  molinbe01    200000
# 11480    1999    CHN   NL  molinjo01    200000
# 12280    2000    ANA   AL  molinbe01    210000
# 12458    2000    CHN   NL  molinjo01    205000
# 13113    2001    ANA   AL  molinbe01    350000
# 13973    2002    ANA   AL  molinbe01    350000
# 14816    2003    ANA   AL  molinbe01   1425000
# 14817    2003    ANA   AL  molinjo01    320000
# 15648    2004    ANA   AL  molinbe01   2025000
# 15649    2004    ANA   AL  molinjo01    335000
# 16839    2005    LAA   AL  molinbe01   3000000
# 16840    2005    LAA   AL  molinjo01    725000
# 17167    2005    SLN   NL  molinya01    323500
# 17665    2006    LAA   AL  molinjo01    850000
# 17985    2006    SLN   NL  molinya01    400000
# 18071    2006    TOR   AL  molinbe01   4500000
# ...
